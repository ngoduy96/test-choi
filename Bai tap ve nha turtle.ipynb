# %%
import turtle
t = turtle.Turtle()
turtle.bgcolor("sky blue")
t.color("black","blue")
t.begin_fill()
for i in range(4):
 t.fd(100)
 t.lt(90)
t.end_fill() 
t.color("black","pink")
t.goto(0,100)
t.begin_fill()
t.goto(50,150)
t.goto(100,100)
t.end_fill()
t.color("black","orange")
t.begin_fill()
t.goto(250,150)
t.goto(200,200)
t.goto(50,150)
t.end_fill()
t.penup()
t.goto(100,0)
t.pendown()
t.color("black","yellow")
t.begin_fill()
t.goto(250,50)     
t.goto(250,150)
t.goto(100,100)
t.end_fill()  
t.penup()
t.home()
t.pendown()
t.color("black","lime")
t.begin_fill()
t.goto(30,0)
t.goto(30,50)
t.goto(70,50)
t.goto(70,0)
t.end_fill() 
t.penup()
t.goto(150,50)
t.pendown()
t.color("black","brown")
t.begin_fill()
t.goto(200,66)
t.goto(200,106)
t.goto(200,106)
t.goto(150,90)
t.goto(150,50)
t.end_fill()

t.penup()
t.goto(400,0)
t.pendown()
t.color("black","brown")
t.begin_fill()
t.goto(400,50)
t.goto(420,50)
t.goto(420,0)
t.end_fill()
t.penup()
t.goto(380,50)
t.pendown()
t.color("black","lime")
t.begin_fill()
t.goto(440,50)
t.goto(410,90)
t.goto(380,50)
t.end_fill()
t.penup()
t.goto(380,90)
t.pendown()
t.color("black","lime")
t.begin_fill()
t.goto(440,90)
t.goto(410,130)
t.goto(380,90)
t.end_fill()
t.penup()
t.goto(380,130)
t.pendown()
t.color("black","lime")
t.begin_fill()
t.goto(440,130)
t.goto(410,170)
t.goto(380,130)
t.end_fill()

t.penup()
t.goto(330,310)
t.pendown()
t.goto(330,200)
t.penup()
t.goto(330,255)
t.pendown()
t.fd(55)
t.bk(110)
t.fd(55)
t.lt(45)
t.fd(40)
t.bk(80)
t.goto(330,255)
t.rt(90)
t.fd(40)
t.bk(80)
t.lt(45)

t.penup()
t.goto(330,230)
t.color("black","yellow")
t.begin_fill()
t.circle(25)
t.end_fill()
